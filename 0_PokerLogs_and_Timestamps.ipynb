# %%
# PokerLogs and Timestamps 0.1.0
# 
# Author: Trevor Buteau
#
# The purpose of this program is to add accurrate timestamps to the PokerLogs
# output by the program PokerTH. The timestamps have previously been recorded
# by the "WatchDog" program, which has been watching the log folder for changes.
# Unfortunately, this does not detect every single change made to the logs (some
# times multiple changes are logged with the same time stamp), and part of the
# purpose of this script is to detect and fix these discrepancies in the timestamps.

from datetime import datetime
import numpy as np
import pandas as pd
import modules.process_utils as utils

# %%
subject_map = pd.read_csv('data/raw/subject_map.csv')
subject_num = 1
time_sub_num = 1
ts_filename = f'data/raw/timestamps_{time_sub_num}.log'
pokerlog_filename = f'data/logs/pokerth_log_{subject_num}.txt'
times = utils.get_timestamps(ts_filename, 120)
poker_acts = utils.get_poker_actions(pokerlog_filename, times, subject_map.iloc[subject_num-1,2], subject_map.iloc[subject_num-1,3])
poker_acts = poker_acts.iloc[1:]
poker_acts = poker_acts.set_index('Action Num')
poker_acts.iloc[-1,1] = poker_acts.iloc[-2,1]

# To save output to .csv file
poker_acts.to_csv(f'data/processed/valid_poker_acts_{subject_num}.csv')

poker_acts
# Out:
# 1269
# Made a timestamp adjustment BECAUSE WE'RE ALL IN
# At 'TURN' , Hand38
# Found a PREFLOP timestamp difference of datetime.timedelta(0, 0, 11000) at Hand 43
# 1900-01-01 13:32:12.308000
# 1900-01-01 13:32:12.319000
# Found a PREFLOP timestamp difference of datetime.timedelta(0, 0, 11000) at Hand 56
# 1900-01-01 13:37:49.060000
# 1900-01-01 13:37:49.071000
# Found a PREFLOP timestamp difference of datetime.timedelta(0, 0, 10000) at Hand 64
# 1900-01-01 13:41:45.019000
# 1900-01-01 13:41:45.029000
# Made a timestamp adjustment BECAUSE WE'RE ALL IN
# At 'TURN' , Hand71
# Found a PREFLOP timestamp difference of datetime.timedelta(0, 0, 10000) at Hand 75
# 1900-01-01 13:46:56.875000
# 1900-01-01 13:46:56.885000
# Made a timestamp adjustment BECAUSE WE'RE ALL IN
# At 'RIVER' , Hand95
# 1148
#            HandNum     TimeStamp Small Blind Big Blind StartHeroTurn  \
# Action Num
# 0                1  13:10:45,920          10        20          True
# 1                1  13:11:02,067          10        20         False
# 2                1  13:11:02,119          10        20          True
# 3                1  13:11:05,412          10        20         False
# 4                1  13:11:05,460          10        20         False
# 5                1  13:11:14,677          10        20          True
# 6                1  13:11:14,860          10        20         False
# 7                1  13:11:14,860          10        20         False
# 8                1  13:11:22,461          10        20          True
# 9                1  13:11:22,590          10        20         False
# 10               1  13:11:22,641          10        20         False
# 11               1  13:11:30,654          10        20          True
# 12               1  13:11:30,784          10        20         False
# 12               1  13:11:30,784          10        20         False
# 13               1  13:11:30,837          10        20         False
# 14               2  13:11:37,988          10        20         False
# 15               2  13:11:41,745          10        20          True
# 16               2  13:11:41,887          10        20         False
# 17               2  13:11:45,705          10        20          True
# 18               2  13:11:45,727          10        20          True
# 19               2  13:11:53,273          10        20         False
# 20               2  13:11:53,330          10        20         False
# 21               2  13:11:57,583          10        20         False
# 22               3  13:12:00,414          10        20          True
# 23               3  13:12:03,408          10        20         False
# 24               3  13:12:04,956          10        20          True
# 25               3  13:12:04,978          10        20         False
# 26               3  13:12:10,193          10        20          True
# 27               3  13:12:13,031          10        20         False
# 28               3  13:12:14,031          10        20         False
# ...            ...           ...         ...       ...           ...
# 1129            93  13:55:51,470          40        80          True
# 1130            93  13:55:51,507          40        80         False
# 1131            94  13:55:58,984          40        80          True
# 1132            94  13:56:00,251          40        80         False
# 1133            94  13:56:00,472          40        80          True
# 1134            94  13:56:00,483          40        80         False
# 1135            94  13:56:05,580          40        80          True
# 1136            94  13:56:05,742          40        80         False
# 1137            94  13:56:07,533          40        80          True
# 1138            94  13:56:07,533          40        80         False
# 1139            94  13:56:10,197          40        80          True
# 1140            94  13:56:10,216          40        80         False
# 1141            95  13:56:17,567          40        80         False
# 1142            95  13:56:20,120          40        80          True
# 1143            95  13:56:20,281          40        80         False
# 1144            95  13:56:22,192          40        80          True
# 1145            95  13:56:22,241          40        80          True
# 1146            95  13:56:27,905          40        80         False
# 1147            95  13:56:28,207          40        80          True
# 1148            95  13:56:30,072          40        80         False
# 1149            95  13:56:31,684          40        80          True
# 1150            95  13:56:31,741          40        80          True
# 1151            95  13:56:34,910          40        80         False
# 1152            95  13:56:36,391          40        80          True
# 1153            95  13:56:36,403          40        80          True
# 1154            95  13:56:41,880          40        80         False
# 1155            95  13:56:43,454          40        80          True
# 1155            95  13:56:43,454          40        80         False
# 1155            95  13:56:43,454          40        80         False
# 1156            95  13:56:43,454          40        80         False
#
#            Game Phase Hero Chips Villain Chips Pot Chips Hole Cards  \
# Action Num
# 0             PREFLOP       4990          4980        30    [?s,?h]
# 1             PREFLOP       4980          4980        40    [?s,?h]
# 2             PREFLOP       4980          4960        60    [?s,?h]
# 3             PREFLOP       4960          4960        80    [?s,?h]
# 4                FLOP       4960          4960        80    [?s,?h]
# 5                FLOP       4960          4960        80    [?s,?h]
# 6                FLOP       4960          4960        80    [?s,?h]
# 7                TURN       4960          4960        80    [?s,?h]
# 8                TURN       4960          4960        80    [?s,?h]
# 9                TURN       4960          4960        80    [?s,?h]
# 10              RIVER       4960          4960        80    [?s,?h]
# 11              RIVER       4960          4960        80    [?s,?h]
# 12              RIVER       4960          4960        80    [?s,?h]
# 12              RIVER       4960          4960        80    [?s,?h]
# 13              RIVER       4960          5040         0    [?s,?h]
# 14            PREFLOP       4940          5030        30    [?s,?h]
# 15            PREFLOP       4940          5020        40    [?s,?h]
# 16            PREFLOP       4920          5020        60    [?s,?h]
# 17            PREFLOP       4920          5000        80    [?s,?h]
# 18               FLOP       4920          5000        80    [?s,?h]
# 19               FLOP       4920          5000        80    [?s,?h]
# 20               FLOP       4920          5080         0    [?s,?h]
# 21               FLOP       4920          5080         0    [?s,?h]
# 22            PREFLOP       4910          5060        30    [Qh,3c]
# 23            PREFLOP       4900          5060        40    [Qh,3c]
# 24            PREFLOP       4900          5060        40    [Qh,3c]
# 25               FLOP       4900          5060        40    [Qh,3c]
# 26               FLOP       4900          5040        60    [Qh,3c]
# 27               FLOP       4880          5040        80    [Qh,3c]
# 28               TURN       4880          5040        80    [Qh,3c]
# ...               ...        ...           ...       ...        ...
# 1129            RIVER       6010          1470      2520    [?s,?h]
# 1130            RIVER       8530          1470         0    [?s,?h]
# 1131          PREFLOP       8490          1390       120    [?s,?h]
# 1132          PREFLOP       8450          1390       160    [?s,?h]
# 1133          PREFLOP       8450          1390       160    [?s,?h]
# 1134             FLOP       8450          1390       160    [?s,?h]
# 1135             FLOP       8450          1390       160    [?s,?h]
# 1136             FLOP       8370          1390       240    [?s,?h]
# 1137             FLOP       8370          1310       320    [?s,?h]
# 1138             TURN       8370          1310       320    [?s,?h]
# 1139             TURN       8370          1310       320    [?s,?h]
# 1140             TURN       8690          1310         0    [?s,?h]
# 1141          PREFLOP       8610          1270       120    [Ad,9h]
# 1142          PREFLOP       8610          1230       160    [Ad,9h]
# 1143          PREFLOP       8530          1230       240    [Ad,9h]
# 1144          PREFLOP       8530          1150       320    [Ad,9h]
# 1145             FLOP       8530          1150       320    [Ad,9h]
# 1146             FLOP       8430          1150       420    [Ad,9h]
# 1147             FLOP       8430           950       620    [Ad,9h]
# 1148             FLOP       8230           950       820    [Ad,9h]
# 1149             FLOP       8230           850       920    [Ad,9h]
# 1150             TURN       8230           850       920    [Ad,9h]
# 1151             TURN       8150           850      1000    [Ad,9h]
# 1152             TURN       8150           770      1080    [Ad,9h]
# 1153            RIVER       8150           770      1080    [Ad,9h]
# 1154            RIVER       7380           770      1850    [Ad,9h]
# 1155            RIVER       7380             0      2620    [Ad,9h]
# 1155            RIVER       7380             0      2620    [Ad,9h]
# 1155            RIVER       7380             0      2620    [Ad,9h]
# 1156            RIVER      10000             0         0    [Ad,9h]
#
#                  Board Cards  \
# Action Num
# 0
# 1
# 2
# 3
# 4                 [2h,Ah,Ts]
# 5                 [2h,Ah,Ts]
# 6                 [2h,Ah,Ts]
# 7              [2h,Ah,Ts,Ad]
# 8              [2h,Ah,Ts,Ad]
# 9              [2h,Ah,Ts,Ad]
# 10          [2h,Ah,Ts,Ad,Ks]
# 11          [2h,Ah,Ts,Ad,Ks]
# 12          [2h,Ah,Ts,Ad,Ks]
# 12          [2h,Ah,Ts,Ad,Ks]
# 13          [2h,Ah,Ts,Ad,Ks]
# 14
# 15
# 16
# 17
# 18                [Qh,9s,4c]
# 19                [Qh,9s,4c]
# 20                [Qh,9s,4c]
# 21                [Qh,9s,4c]
# 22
# 23
# 24
# 25                [4d,Kc,Ad]
# 26                [4d,Kc,Ad]
# 27                [4d,Kc,Ad]
# 28             [4d,Kc,Ad,6h]
# ...                      ...
# 1129        [5d,6d,4d,6s,5h]
# 1130        [5d,6d,4d,6s,5h]
# 1131
# 1132
# 1133
# 1134              [4d,7d,9c]
# 1135              [4d,7d,9c]
# 1136              [4d,7d,9c]
# 1137              [4d,7d,9c]
# 1138           [4d,7d,9c,Ac]
# 1139           [4d,7d,9c,Ac]
# 1140           [4d,7d,9c,Ac]
# 1141
# 1142
# 1143
# 1144
# 1145              [Qs,7d,As]
# 1146              [Qs,7d,As]
# 1147              [Qs,7d,As]
# 1148              [Qs,7d,As]
# 1149              [Qs,7d,As]
# 1150           [Qs,7d,As,2c]
# 1151           [Qs,7d,As,2c]
# 1152           [Qs,7d,As,2c]
# 1153        [Qs,7d,As,2c,Kd]
# 1154        [Qs,7d,As,2c,Kd]
# 1155        [Qs,7d,As,2c,Kd]
# 1155        [Qs,7d,As,2c,Kd]
# 1155        [Qs,7d,As,2c,Kd]
# 1156        [Qs,7d,As,2c,Kd]
#
#                                                      Log Line
# Action Num
# 0                                                   PREFLOP\n
# 1                                     Guest15166 calls $10.\n
# 2                                      Guest84440 bets $20.\n
# 3                                     Guest15166 calls $20.\n
# 4                               FLOP [board cards 2h,Ah,Ts]\n
# 5                                        Guest84440 checks.\n
# 6                                        Guest15166 checks.\n
# 7                            TURN [board cards 2h,Ah,Ts,Ad]\n
# 8                                        Guest84440 checks.\n
# 9                                        Guest15166 checks.\n
# 10                       RIVER [board cards 2h,Ah,Ts,Ad,Ks]\n
# 11                                       Guest84440 checks.\n
# 12                                       Guest15166 checks.\n
# 12          Guest84440 shows [ 6h,6d] - Two Pair, Aces and...
# 13                                      Guest84440 wins $80\n
# 14                                                  PREFLOP\n
# 15                                    Guest84440 calls $10.\n
# 16                                     Guest15166 bets $20.\n
# 17                                    Guest84440 calls $20.\n
# 18                              FLOP [board cards Qh,9s,4c]\n
# 19                                        Guest15166 folds.\n
# 20                                      Guest84440 wins $80\n
# 21                                 Guest84440 shows [Ac,Kc]\n
# 22                                                  PREFLOP\n
# 23                                    Guest15166 calls $10.\n
# 24                                       Guest84440 checks.\n
# 25                              FLOP [board cards 4d,Kc,Ad]\n
# 26                                     Guest84440 bets $20.\n
# 27                                    Guest15166 calls $20.\n
# 28                           TURN [board cards 4d,Kc,Ad,6h]\n
# ...                                                       ...
# 1129                                      Guest84440 folds.\n
# 1130                                  Guest15166 wins $2520\n
# 1131                                                PREFLOP\n
# 1132                                  Guest15166 calls $40.\n
# 1133                                     Guest84440 checks.\n
# 1134                            FLOP [board cards 4d,7d,9c]\n
# 1135                                     Guest84440 checks.\n
# 1136                                   Guest15166 bets $80.\n
# 1137                                  Guest84440 calls $80.\n
# 1138                         TURN [board cards 4d,7d,9c,Ac]\n
# 1139                                      Guest84440 folds.\n
# 1140                                   Guest15166 wins $320\n
# 1141                                                PREFLOP\n
# 1142                                  Guest84440 calls $40.\n
# 1143                                   Guest15166 bets $80.\n
# 1144                                  Guest84440 calls $80.\n
# 1145                            FLOP [board cards Qs,7d,As]\n
# 1146                                  Guest15166 bets $100.\n
# 1147                                  Guest84440 bets $200.\n
# 1148                                  Guest15166 bets $200.\n
# 1149                                 Guest84440 calls $100.\n
# 1150                         TURN [board cards Qs,7d,As,2c]\n
# 1151                                   Guest15166 bets $80.\n
# 1152                                  Guest84440 calls $80.\n
# 1153                     RIVER [board cards Qs,7d,As,2c,Kd]\n
# 1154                                  Guest15166 bets $770.\n
# 1155                        Guest84440 is all in with $770.\n
# 1155             Guest15166 shows [ Ad,9h] - One Pair, Aces\n
# 1155           Guest84440 shows [ 3c,Qc] - One Pair, Queens\n
# 1156                                  Guest15166 wins $2620\n
#
# [1221 rows x 12 columns]
